# %% [markdown]
# Given has an array of sales numbers, what is the index of the smallest index element for which the sums of all elements to the left and to the right are equal. The array may not be reordered.
# For example, given the array sales = [1, 2, 3, 4, 6],we see that 1+2+3=6，Using zero based indexing,sales[3] = 4 is the value sought.The index is 3.
#
# Example:
# Input : [1, 2, 3, 4, 6]
# Output : 3

# %%
class Solution:
    
    def BalancedSalesArray(self, sales):
        # write your code here
        
        sum_left=0
        sum_right=0
        for a  in range(0,len(sales)-2):
            sum_left+=sales[a]
            for b in range(a+2,len(sales)):
                sum_right+=sales[b]
            
            
            if a+2 == len(sales):
                sum_right=sales[a+2]
            
            if sum_left==sum_right:
                return a+1
                
            sum_right=0

# %% [markdown]
# Given an array consisting of n integers, find the contiguous subarray of given length k that has the maximum average value. You need to output the maximum average value.
#
# Input:  nums = [1,12,-5,-6,50,3] and k = 4
# Output: 12.75
# Explanation:
# Maximum average is (12-5-6+50)/4 = 51/4 = 12.75
#
# Input:  nums = [4,2,1,3,3] and k = 2
# Output: 3.00
# Explanation:
# Maximum average is (3+3)/2 = 6/2 = 3.00

# %%
class Solution:
    """
    @param nums: an array
    @param k: an integer
    @return: the maximum average value
    """
    def findMaxAverage(self, nums, k):
        # Write your code here
        sum_list=0
        average_sum=[]
        if nums==[]:
            return 0
            
        if len(nums)==k:
            return sum(nums)/k
        
        elif len(nums)>k:
            for a in range(0,len(nums)-k+1):
                for b in range(a,a+k):
                    sum_list+=nums[b]
                
                average_sum.append(sum_list/k)
                sum_list=0
            
            return max(average_sum)

# %% [markdown]
# Two people choose numbers in a matrix. Everyone chooses the best number.
# The selected column can‘t selected anymore. you should return the difference between two people at last.
#
# Example:
# Input:
# grids:[[1,4,7],[2,5,8],[3,6,9]]
# Output:6
# Explanation: each column maxium is [3, 6, 9], at first, A choose 9 so B can't choose 3rd column. then B choose 6, finally, A choose 3, you should return (3 + 9) - 6 = 6

# %%
class Solution:
    """
    @param grids: a integer matrix
    @return: return the difference between two people at last.
    """
    def MatrixGame(self, grids):
        # write your code here
        new_grids=[]
        max_columns=[]
        
        if grids==[]:
            return 0
            
        for a in range(len(grids[0])):
            for b in range(len(grids)):
                new_grids.append(grids[b][a])
                
            max_columns.append(max(new_grids))
            new_grids=[]

# %% [markdown]
# Given an unsorted array of n elements, find if the element k is present in the array or not.
# Complete the findnNumber function in the editor below.It has 2 parameters:
# 1 An array of integers, arr, denoting the elements in the array.
# 2 An integer, k, denoting the element to be searched in the array.
# The function must return true or false denoting if the element is present in the array or not
#
# Example:
# Input:
# arr = [1, 2, 3, 4, 5]
# k = 1
# Output: true

# %%
class Solution:
    """
    @param nums: a integer array
    @param k: a integer
    @return: return true or false denoting if the element is present in the array or not
    """
    def findnNumber(self, nums, k):
        # write your code here
        for i in range(len(nums)):
            if k == nums[i]:
                return True
            elif k not in nums:
                return False

# %%
class Solution:
    """
    @param scores: two dimensional array
    @param K: a integer
    @return: return a integer
    """
    
    def FindTheRank(self, scores, K):
        # write your code here
        average_grade=[]
        total=0
        for a in range(len(scores)):
            for b in range(len(scores[a])):
                total=total+scores[a][b]
            
            total=total/len(scores[a])
            average_grade.append(total)
            total=0
            
        '''for a in range(len(scores)):
            average_grade.append(sum(scores[a])/len(scores[a]))'''
        
        averagegrade_sorted = sorted(average_grade)
        
        for b in range(len(average_grade)):
            if averagegrade_sorted[-K]==average_grade[b]:
                return b

# %% [markdown]
# Give a two-dimensional array of scores to indicate the scores of each student's subjects, and find the index of the K-th grade of the students' total scores.
#
# Example：
# Input:
# scores: [[90, 80, 70], [90, 90, 90], [60, 60, 60]]
# k: 2
# Output: 0
# Explanation:
# The second in the total score is the student with index 0.

# %%
class Solution:
    """
    @param str: A String
    @param left: a left offset
    @param right: a right offset
    @return: return a rotate string
    """
    def RotateString2(self, str, left, right):
        # write your code here
        index=left-right
        index=(left-right)%len(str)
        
        if index==0:
            return str
            
        else:
            newstr=str[index:]+str[:index]
            return newstr

# %% [markdown]
# Give a set of usernames(only alphabet characters), if there are duplicate requests to add a numeric distinction after the username, return the modified array.
#
# Input：["aa", "bb", "cc", "bb", "aa", "aa", "aa"]
# Output：["aa","bb","cc","bb1","aa1","aa2","aa3"]
# Explanation：
# The output of the second occurrence of "bb" is "bb1"
# The output of the second occurrence of "aa" is "aa1"
# The output of the third occurrence of "aa" is "aa2"
# The output of the fourth occurrence of "aa" is "aa3"
#
# Input：[aa, bb, cc, aa]
# Output：[aa, bb, cc, aa1]
# Explanation：The output of the second occurrence of "aa" is "aa1"

# %%
class Solution:
    """
    @param names: a string array
    @return: the string array
    """
    def DistinguishUsername(self, names):
        # Write your code here
        results=[]
        dic={}
        for j in range(len(names)):
            dic[names[j]]=-1
            
        for i in range(len(names)):
            dic[names[i]]=dic[names[i]]+1
            if dic[names[i]]>0:
                results.append(names[i]+str(dic[names[i]]))
            else:
                results.append(names[i])
        
        return results

# %% [markdown]
# Merge two sorted (ascending) linked lists and return it as a new sorted list. The new sorted list should be made by splicing together the nodes of the two lists and sorted in ascending order.

# %%
"""
Definition of ListNode
class ListNode(object):
    def __init__(self, val, next=None):
        self.val = val
        self.next = next
"""

class Solution:
    """
    @param l1: ListNode l1 is the head of the linked list
    @param l2: ListNode l2 is the head of the linked list
    @return: ListNode head of linked list
    """
    def mergeTwoLists(self, l1, l2):
        # write your code here
        if l1 == None:
            return l2
        if l2 == None:
            return l1
        
        dummy = ListNode(0)
        temp = dummy
            
        while l1 != None and l2 != None:
            if l1.val > l2.val:
                temp.next = l2
                l2 = l2.next
            else:
                temp.next = l1
                l1 = l1.next
            
            temp = temp.next
                
        if l1 != None:
            temp.next = l1
        if l2 != None:
            temp.next = l2
            
        return dummy.next

# %% [markdown]
# There are many cars parked in the parking lot. The parking is a straight very long line and a parking slot for every single meter. There are cars parked currently and you want to cover them from the rain by building a roof. The requirement is that at least k cars are covered by the roof.What's the minium length of the roof that would cover k cars?
# The function has the following parameters:
#
# cars: integer array of length denoting the parking slots where cars are parked
# k: integer denoting the number of cars that have to be covered by the roof
#
# Example:
# Input:
# cars: [2, 10, 8, 17]
# k: 3
# output: 9
# Explanation: you can build a roof of length 9 covering all parking slots from the 2nd one to the 10th one, so covering 3 cars at slots 2, 10, 8, there are no shorter roof  that can cover 3 cars, so the answer is 9

# %%
class Solution:
    """
    @param cars:  integer array of length denoting the parking slots where cars are parked
    @param k: integer denoting the number of cars that have to be covered by the roof
    @return: return the minium length of the roof that would cover k cars
    """
    def ParkingDilemma(self, cars, k):
        # write your code here
        cars=sorted(cars)
        cover=[]
        if len(cars)==k:
            return cars[-1]-cars[0]+1
        else:
            for i in range(len(cars)-k):
                cover_len=cars[i+k-1]-cars[i]+1
                cover.append(cover_len)
        
        return min(cover)
